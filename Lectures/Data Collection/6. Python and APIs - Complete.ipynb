# %% [markdown]
# # Python and APIs
#
# While we now have the ability to scrape a website with `bs4` there will be some websites that are impossible or incredibly inconvenient to scrape in this manner. Luckily, some of these websites have application programming interfaces (APIs) that are easily accessible via python.
#
# ## What we will accomplish
#
# In this notebook we will:
# - Introduce the concept of an API,
# - Discuss python wrappers for APIs,
# - Give an example of a python wrapper for an API and
# - Provide a list of useful API python packages.

# %% [markdown]
# ## What is an API?
#
# An application programming interface is a go between for two "application"s. For our purposes, we can think of one application as your data science project and the other as the website or app that you want some data from.
#
# A common analogy used when describing APIs is that of a waiter. The waiter comes to your table, recieves your order, gives your order to the chef, then retrieves the cooked food and takes it back to your table. In this analogy you are you, the waiter is the API and the chef is the web application. Schematically it looks like this:
#
# <img src="api1.png" width="60%"></img>
# <br>
# <br>
# <img src="api2.png" width="60%"></img>
# <br>
# <br>
# <img src="api3.png" width="60%"></img>
# <br>
# <br>
# <img src="api4.png" width="60%"></img>
#
# While we may be able to write custom code to scrape these websites or applications ourselves, it often behooves us to use APIs when they exist and are accessible. For one, many websites may have it in their terms of service that you have to use this route for data collection. Moreover, interacting with the API is probably much easier and more efficient.

# %% [markdown]
# ## Python wrappers for APIs
#
# An API may not be created with the ability to directly accept python commands as input, however, many individuals have put in the time to create <i>python wrappers</i> which convert python commands into the relevant commands that can be understood by the API. A python wrapper for an API is a python package or module that was written to take your requests in python and translate them into a language the API can understand.
#
# Python wrappers have been written for some of the most popular APIs including:
# - Twitter, <a href="https://docs.tweepy.org/en/stable/#">https://docs.tweepy.org/en/stable/#</a>,
# - Reddit, <a href="https://praw.readthedocs.io/en/stable/">https://praw.readthedocs.io/en/stable/</a>,
# - The New York Times, <a href="https://github.com/michadenheijer/pynytimes">https://github.com/michadenheijer/pynytimes</a> and
# - More.
#
# ## Example: Using a python wrapper for the New York Times API
#
# We will now demonstrate an example use of a python wrapper for an API with the `pynytimes` package. <i>Note that you will need to install this package to follow along. Docs: <a href="https://github.com/michadenheijer/pynytimes">https://github.com/michadenheijer/pynytimes<a></i>

# %%
import pynytimes

# %%
## Version check, I had version 0.8.0 when I wrote this
print(pynytimes.__version__)
# Out:
# 0.8.0

# %% [markdown]
# ### Getting a New York Times developer key
#
# In order to use the API you first have to get a developer key. This is a common step for API use. Developer keys allow the API to track who is trying to use their API, how they are trying to use it and what level of access they have. You will need to get a developer key in order to move forward, <a href="https://developer.nytimes.com/">https://developer.nytimes.com/</a>. In particular you should go to the "Get Started" area, <a href="https://developer.nytimes.com/get-started">https://developer.nytimes.com/get-started</a>, unless you already had a developer key.
#
# After you work through the steps to get an API go into the file, `my_api_info.py` and edit the function `get_nytimes_key()` so that it returns your API key as a string instead of "YOUR KEY HERE".
#
# <i><b>Note: never share your API key with anyone else, and do not upload it to a repository in a file.</b></i> That is your API key, and it is associated with your digital footprint for this particular API.
#
# ### Making a `NYTAPI` object
#
# Let's now see how we can use our key to help us make a `NYTAPI` object.

# %%
from pynytimes import NYTAPI

# %%
## edit this code accordingly
from matt_api_info import get_nytimes_key

# %%
## to create an NYTAPI object call
## NYTAPI(key, parse_dates=True)
nytapi = NYTAPI(get_nytimes_key(), parse_dates=True)

# %% [markdown]
# ### Searching for 20 basketball articles
#
# One endpoint of the New York Times API is `article_search`. This endpoint will allow us to specify a keyword, a number of desired results and date range and then return what articles match that query.
#
# We will use it to search for basketball articles posted in the month of February 2022. For this we will need the `datetime` module.

# %%
from datetime import datetime

# %%
## call nytapi.article_search
## specify your keyword with query = 
## how many results you want with results =
## give the end and begin dates with dates = {'begin':   , 'end': }
results = nytapi.article_search(query = "basketball",
                                   results = 30,
                                   dates = {'begin': datetime(2022, 2, 1),
                                            'end': datetime(2022, 3, 1)})

# %%
## a list of dictionary objects is returned
results
# Out:
# [{'abstract': 'Seven of the top 10 teams lost in a single day, setting off fan celebrations and reinforcing the notion that the N.C.A.A. tournament will be wide open.',
#   'web_url': 'https://www.nytimes.com/2022/02/27/sports/ncaabasketball/ncaa-top-10-mens-college-basketball.html',
#   'snippet': 'Seven of the top 10 teams lost in a single day, setting off fan celebrations and reinforcing the notion that the N.C.A.A. tournament will be wide open.',
#   'lead_paragraph': 'The calendar won’t flip to March until Tuesday, but Saturday featured a full menu of madness in men’s college basketball.',
#   'print_section': 'D',
#   'print_page': '3',
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-articleLarge.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {'xlarge': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-articleLarge.jpg',
#      'xlargewidth': 600,
#      'xlargeheight': 400},
#     'subType': 'xlarge',
#     'crop_name': 'articleLarge'},
#    {'rank': 0,
#     'subtype': 'popup',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-popup.jpg',
#     'height': 433,
#     'width': 650,
#     'legacy': {},
#     'subType': 'popup',
#     'crop_name': 'popup'},
#    {'rank': 0,
#     'subtype': 'blog480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-blog480.jpg',
#     'height': 320,
#     'width': 480,
#     'legacy': {},
#     'subType': 'blog480',
#     'crop_name': 'blog480'},
#    {'rank': 0,
#     'subtype': 'blog533',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-blog533.jpg',
#     'height': 355,
#     'width': 533,
#     'legacy': {},
#     'subType': 'blog533',
#     'crop_name': 'blog533'},
#    {'rank': 0,
#     'subtype': 'blog427',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-blog427.jpg',
#     'height': 285,
#     'width': 427,
#     'legacy': {},
#     'subType': 'blog427',
#     'crop_name': 'blog427'},
#    {'rank': 0,
#     'subtype': 'tmagSF',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-tmagSF.jpg',
#     'height': 241,
#     'width': 362,
#     'legacy': {},
#     'subType': 'tmagSF',
#     'crop_name': 'tmagSF'},
#    {'rank': 0,
#     'subtype': 'tmagArticle',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-tmagArticle.jpg',
#     'height': 395,
#     'width': 592,
#     'legacy': {},
#     'subType': 'tmagArticle',
#     'crop_name': 'tmagArticle'},
#    {'rank': 0,
#     'subtype': 'slide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-slide.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {},
#     'subType': 'slide',
#     'crop_name': 'slide'},
#    {'rank': 0,
#     'subtype': 'jumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-jumbo.jpg',
#     'height': 683,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'jumbo',
#     'crop_name': 'jumbo'},
#    {'rank': 0,
#     'subtype': 'superJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-superJumbo.jpg',
#     'height': 1365,
#     'width': 2048,
#     'legacy': {},
#     'subType': 'superJumbo',
#     'crop_name': 'superJumbo'},
#    {'rank': 0,
#     'subtype': 'blog225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-blog225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'blog225',
#     'crop_name': 'blog225'},
#    {'rank': 0,
#     'subtype': 'master1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-master1050.jpg',
#     'height': 700,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'master1050',
#     'crop_name': 'master1050'},
#    {'rank': 0,
#     'subtype': 'master675',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-master675.jpg',
#     'height': 450,
#     'width': 675,
#     'legacy': {},
#     'subType': 'master675',
#     'crop_name': 'master675'},
#    {'rank': 0,
#     'subtype': 'master495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-master495.jpg',
#     'height': 330,
#     'width': 495,
#     'legacy': {},
#     'subType': 'master495',
#     'crop_name': 'master495'},
#    {'rank': 0,
#     'subtype': 'master180',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-master180.jpg',
#     'height': 120,
#     'width': 180,
#     'legacy': {},
#     'subType': 'master180',
#     'crop_name': 'master180'},
#    {'rank': 0,
#     'subtype': 'master315',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-master315.jpg',
#     'height': 210,
#     'width': 315,
#     'legacy': {},
#     'subType': 'master315',
#     'crop_name': 'master315'},
#    {'rank': 0,
#     'subtype': 'master768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-master768.jpg',
#     'height': 512,
#     'width': 768,
#     'legacy': {},
#     'subType': 'master768',
#     'crop_name': 'master768'},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnail': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-thumbStandard.jpg',
#      'thumbnailwidth': 75,
#      'thumbnailheight': 75},
#     'subType': 'thumbnail',
#     'crop_name': 'thumbStandard'},
#    {'rank': 0,
#     'subtype': 'blogSmallThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-blogSmallThumb.jpg',
#     'height': 50,
#     'width': 50,
#     'legacy': {},
#     'subType': 'blogSmallThumb',
#     'crop_name': 'blogSmallThumb'},
#    {'rank': 0,
#     'subtype': 'thumbLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-thumbLarge.jpg',
#     'height': 150,
#     'width': 150,
#     'legacy': {},
#     'subType': 'thumbLarge',
#     'crop_name': 'thumbLarge'},
#    {'rank': 0,
#     'subtype': 'smallSquare168',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-smallSquare168.jpg',
#     'height': 168,
#     'width': 168,
#     'legacy': {},
#     'subType': 'smallSquare168',
#     'crop_name': 'smallSquare168'},
#    {'rank': 0,
#     'subtype': 'smallSquare252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-smallSquare252.jpg',
#     'height': 252,
#     'width': 252,
#     'legacy': {},
#     'subType': 'smallSquare252',
#     'crop_name': 'smallSquare252'},
#    {'rank': 0,
#     'subtype': 'square320',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-square320.jpg',
#     'height': 320,
#     'width': 320,
#     'legacy': {},
#     'subType': 'square320',
#     'crop_name': 'square320'},
#    {'rank': 0,
#     'subtype': 'moth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-moth.jpg',
#     'height': 151,
#     'width': 151,
#     'legacy': {},
#     'subType': 'moth',
#     'crop_name': 'moth'},
#    {'rank': 0,
#     'subtype': 'filmstrip',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-filmstrip.jpg',
#     'height': 190,
#     'width': 190,
#     'legacy': {},
#     'subType': 'filmstrip',
#     'crop_name': 'filmstrip'},
#    {'rank': 0,
#     'subtype': 'square640',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-square640.jpg',
#     'height': 640,
#     'width': 640,
#     'legacy': {},
#     'subType': 'square640',
#     'crop_name': 'square640'},
#    {'rank': 0,
#     'subtype': 'mediumSquare149',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-mediumSquare149.jpg',
#     'height': 149,
#     'width': 149,
#     'legacy': {},
#     'subType': 'mediumSquare149',
#     'crop_name': 'mediumSquare149'},
#    {'rank': 0,
#     'subtype': 'mediumSquareAt3X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-mediumSquareAt3X.jpg',
#     'height': 1800,
#     'width': 1800,
#     'legacy': {},
#     'subType': 'mediumSquareAt3X',
#     'crop_name': 'mediumSquareAt3X'},
#    {'rank': 0,
#     'subtype': 'sfSpan',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-sfSpan.jpg',
#     'height': 263,
#     'width': 395,
#     'legacy': {},
#     'subType': 'sfSpan',
#     'crop_name': 'sfSpan'},
#    {'rank': 0,
#     'subtype': 'largeHorizontal375',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-largeHorizontal375.jpg',
#     'height': 250,
#     'width': 375,
#     'legacy': {},
#     'subType': 'largeHorizontal375',
#     'crop_name': 'largeHorizontal375'},
#    {'rank': 0,
#     'subtype': 'largeHorizontalJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-largeHorizontalJumbo.jpg',
#     'height': 683,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'largeHorizontalJumbo',
#     'crop_name': 'largeHorizontalJumbo'},
#    {'rank': 0,
#     'subtype': 'horizontalMediumAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-horizontalMediumAt2X.jpg',
#     'height': 4471,
#     'width': 6707,
#     'legacy': {},
#     'subType': 'horizontalMediumAt2X',
#     'crop_name': 'horizontalMediumAt2X'},
#    {'rank': 0,
#     'subtype': 'hpLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-hpLarge.jpg',
#     'height': 287,
#     'width': 511,
#     'legacy': {},
#     'subType': 'hpLarge',
#     'crop_name': 'hpLarge'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen573',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-largeWidescreen573.jpg',
#     'height': 322,
#     'width': 573,
#     'legacy': {},
#     'subType': 'largeWidescreen573',
#     'crop_name': 'largeWidescreen573'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-largeWidescreen1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'largeWidescreen1050',
#     'crop_name': 'largeWidescreen1050'},
#    {'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'widewidth': 190,
#      'wideheight': 126,
#      'wide': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-thumbWide.jpg'},
#     'subType': 'wide',
#     'crop_name': 'thumbWide'},
#    {'rank': 0,
#     'subtype': 'videoThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoThumb.jpg',
#     'height': 50,
#     'width': 75,
#     'legacy': {},
#     'subType': 'videoThumb',
#     'crop_name': 'videoThumb'},
#    {'rank': 0,
#     'subtype': 'videoLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoLarge.jpg',
#     'height': 507,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoLarge',
#     'crop_name': 'videoLarge'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo210',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-mediumThreeByTwo210.jpg',
#     'height': 140,
#     'width': 210,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo210',
#     'crop_name': 'mediumThreeByTwo210'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-mediumThreeByTwo225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo225',
#     'crop_name': 'mediumThreeByTwo225'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo440',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-mediumThreeByTwo440.jpg',
#     'height': 293,
#     'width': 440,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo440',
#     'crop_name': 'mediumThreeByTwo440'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-mediumThreeByTwo252.jpg',
#     'height': 168,
#     'width': 252,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo252',
#     'crop_name': 'mediumThreeByTwo252'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo378',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-mediumThreeByTwo378.jpg',
#     'height': 252,
#     'width': 378,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo378',
#     'crop_name': 'mediumThreeByTwo378'},
#    {'rank': 0,
#     'subtype': 'threeByTwoLargeAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-threeByTwoLargeAt2X.jpg',
#     'height': 4471,
#     'width': 6707,
#     'legacy': {},
#     'subType': 'threeByTwoLargeAt2X',
#     'crop_name': 'threeByTwoLargeAt2X'},
#    {'rank': 0,
#     'subtype': 'threeByTwoMediumAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-threeByTwoMediumAt2X.jpg',
#     'height': 1000,
#     'width': 1500,
#     'legacy': {},
#     'subType': 'threeByTwoMediumAt2X',
#     'crop_name': 'threeByTwoMediumAt2X'},
#    {'rank': 0,
#     'subtype': 'threeByTwoSmallAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-threeByTwoSmallAt2X.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {},
#     'subType': 'threeByTwoSmallAt2X',
#     'crop_name': 'threeByTwoSmallAt2X'},
#    {'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-articleInline.jpg',
#     'height': 127,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'hpSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-hpSmall.jpg',
#     'height': 109,
#     'width': 163,
#     'legacy': {},
#     'subType': 'hpSmall',
#     'crop_name': 'hpSmall'},
#    {'rank': 0,
#     'subtype': 'blogSmallInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-blogSmallInline.jpg',
#     'height': 101,
#     'width': 151,
#     'legacy': {},
#     'subType': 'blogSmallInline',
#     'crop_name': 'blogSmallInline'},
#    {'rank': 0,
#     'subtype': 'mediumFlexible177',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-mediumFlexible177.jpg',
#     'height': 118,
#     'width': 177,
#     'legacy': {},
#     'subType': 'mediumFlexible177',
#     'crop_name': 'mediumFlexible177'},
#    {'rank': 0,
#     'subtype': 'videoSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSmall.jpg',
#     'height': 281,
#     'width': 500,
#     'legacy': {},
#     'subType': 'videoSmall',
#     'crop_name': 'videoSmall'},
#    {'rank': 0,
#     'subtype': 'videoHpMedium',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoHpMedium.jpg',
#     'height': 211,
#     'width': 375,
#     'legacy': {},
#     'subType': 'videoHpMedium',
#     'crop_name': 'videoHpMedium'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine600.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {},
#     'subType': 'videoSixteenByNine600',
#     'crop_name': 'videoSixteenByNine600'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine540',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine540.jpg',
#     'height': 304,
#     'width': 540,
#     'legacy': {},
#     'subType': 'videoSixteenByNine540',
#     'crop_name': 'videoSixteenByNine540'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine495.jpg',
#     'height': 278,
#     'width': 495,
#     'legacy': {},
#     'subType': 'videoSixteenByNine495',
#     'crop_name': 'videoSixteenByNine495'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine390',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine390.jpg',
#     'height': 219,
#     'width': 390,
#     'legacy': {},
#     'subType': 'videoSixteenByNine390',
#     'crop_name': 'videoSixteenByNine390'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'videoSixteenByNine1050',
#     'crop_name': 'videoSixteenByNine1050'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine480.jpg',
#     'height': 270,
#     'width': 480,
#     'legacy': {},
#     'subType': 'videoSixteenByNine480',
#     'crop_name': 'videoSixteenByNine480'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine310',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine310.jpg',
#     'height': 174,
#     'width': 310,
#     'legacy': {},
#     'subType': 'videoSixteenByNine310',
#     'crop_name': 'videoSixteenByNine310'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine225.jpg',
#     'height': 126,
#     'width': 225,
#     'legacy': {},
#     'subType': 'videoSixteenByNine225',
#     'crop_name': 'videoSixteenByNine225'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine96',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine96.jpg',
#     'height': 54,
#     'width': 96,
#     'legacy': {},
#     'subType': 'videoSixteenByNine96',
#     'crop_name': 'videoSixteenByNine96'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine3000',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine3000.jpg',
#     'height': 1688,
#     'width': 3000,
#     'legacy': {},
#     'subType': 'videoSixteenByNine3000',
#     'crop_name': 'videoSixteenByNine3000'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine768.jpg',
#     'height': 432,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoSixteenByNine768',
#     'crop_name': 'videoSixteenByNine768'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine150',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine150.jpg',
#     'height': 84,
#     'width': 150,
#     'legacy': {},
#     'subType': 'videoSixteenByNine150',
#     'crop_name': 'videoSixteenByNine150'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNineJumbo1600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNineJumbo1600.jpg',
#     'height': 900,
#     'width': 1600,
#     'legacy': {},
#     'subType': 'videoSixteenByNineJumbo1600',
#     'crop_name': 'videoSixteenByNineJumbo1600'},
#    {'rank': 0,
#     'subtype': 'miniMoth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-miniMoth.jpg',
#     'height': 70,
#     'width': 151,
#     'legacy': {},
#     'subType': 'miniMoth',
#     'crop_name': 'miniMoth'},
#    {'rank': 0,
#     'subtype': 'windowsTile336H',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-windowsTile336H.jpg',
#     'height': 336,
#     'width': 694,
#     'legacy': {},
#     'subType': 'windowsTile336H',
#     'crop_name': 'windowsTile336H'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven1305',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoFifteenBySeven1305.jpg',
#     'height': 609,
#     'width': 1305,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven1305',
#     'crop_name': 'videoFifteenBySeven1305'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven2610',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoFifteenBySeven2610.jpg',
#     'height': 1218,
#     'width': 2610,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven2610',
#     'crop_name': 'videoFifteenBySeven2610'},
#    {'rank': 0,
#     'subtype': 'facebookJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-facebookJumbo.jpg',
#     'height': 550,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'facebookJumbo',
#     'crop_name': 'facebookJumbo'},
#    {'rank': 0,
#     'subtype': 'watch308',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-watch308.jpg',
#     'height': 348,
#     'width': 312,
#     'legacy': {},
#     'subType': 'watch308',
#     'crop_name': 'watch308'},
#    {'rank': 0,
#     'subtype': 'watch268',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-watch268.jpg',
#     'height': 303,
#     'width': 272,
#     'legacy': {},
#     'subType': 'watch268',
#     'crop_name': 'watch268'},
#    {'rank': 0,
#     'subtype': 'verticalTwoByThree735',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-verticalTwoByThree735.jpg',
#     'height': 1102,
#     'width': 735,
#     'legacy': {},
#     'subType': 'verticalTwoByThree735',
#     'crop_name': 'verticalTwoByThree735'},
#    {'rank': 0,
#     'subtype': 'mobileMasterAt3x',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-mobileMasterAt3x.jpg',
#     'height': 1200,
#     'width': 1800,
#     'legacy': {},
#     'subType': 'mobileMasterAt3x',
#     'crop_name': 'mobileMasterAt3x'}],
#   'headline': {'main': 'A Stormy Day for the Top Teams in Men’s College Basketball',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Top Six Teams in the Rankings Lose, Pointing to a Wide-Open Postseason',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Basketball (College)',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Auburn University',
#     'rank': 2,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Baylor University',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Duke University',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Gonzaga University',
#     'rank': 5,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'National Collegiate Athletic Assn',
#     'rank': 6,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Purdue University',
#     'rank': 7,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': "St Mary's College of California",
#     'rank': 8,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Syracuse University',
#     'rank': 9,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Texas Tech University',
#     'rank': 10,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'University of Arkansas',
#     'rank': 11,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'University of Maryland, Baltimore County',
#     'rank': 12,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Few, Mark', 'rank': 13, 'major': 'N'},
#    {'name': 'persons', 'value': 'Boeheim, Jim', 'rank': 14, 'major': 'N'},
#    {'name': 'persons', 'value': 'Izzo, Tom', 'rank': 15, 'major': 'N'},
#    {'name': 'persons', 'value': 'Krzyzewski, Mike', 'rank': 16, 'major': 'N'},
#    {'name': 'persons', 'value': 'Musselman, Eric', 'rank': 17, 'major': 'N'}],
#   'pub_date': datetime.datetime(2022, 2, 27, 20, 34, 19, tzinfo=datetime.timezone.utc),
#   'document_type': 'article',
#   'news_desk': 'Sports',
#   'section_name': 'Sports',
#   'subsection_name': 'College Basketball',
#   'byline': {'original': 'By Adam Zagoria',
#    'person': [{'firstname': 'Adam',
#      'middlename': None,
#      'lastname': 'Zagoria',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'News',
#   '_id': 'nyt://article/7b3cfdd2-e906-5331-be64-705a0ce76faf',
#   'word_count': 762,
#   'uri': 'nyt://article/7b3cfdd2-e906-5331-be64-705a0ce76faf'},
#  {'abstract': 'Clark, a sophomore at Iowa, says the game slows down for her, and it shows: She leads Division I women’s basketball in points and assists.',
#   'web_url': 'https://www.nytimes.com/2022/02/27/sports/ncaabasketball/caitlin-clark-iowa.html',
#   'snippet': 'Clark, a sophomore at Iowa, says the game slows down for her, and it shows: She leads Division I women’s basketball in points and assists.',
#   'lead_paragraph': 'PISCATAWAY, N.J. — In the closing minutes of the University of Iowa’s 87-78 victory over Rutgers on Thursday, Caitlin Clark flashed the basketball skills that have invited comparisons to Steph Curry and Sue Bird and earned admiration from Kevin Durant.',
#   'print_section': 'D',
#   'print_page': '3',
#   'source': 'The New York Times',
#   'multimedia': [{'rank': 0,
#     'subtype': 'xlarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-articleLarge.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {'xlarge': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-articleLarge.jpg',
#      'xlargewidth': 600,
#      'xlargeheight': 400},
#     'subType': 'xlarge',
#     'crop_name': 'articleLarge'},
#    {'rank': 0,
#     'subtype': 'popup',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-popup.jpg',
#     'height': 433,
#     'width': 650,
#     'legacy': {},
#     'subType': 'popup',
#     'crop_name': 'popup'},
#    {'rank': 0,
#     'subtype': 'blog480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-blog480.jpg',
#     'height': 320,
#     'width': 480,
#     'legacy': {},
#     'subType': 'blog480',
#     'crop_name': 'blog480'},
#    {'rank': 0,
#     'subtype': 'blog533',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-blog533.jpg',
#     'height': 355,
#     'width': 533,
#     'legacy': {},
#     'subType': 'blog533',
#     'crop_name': 'blog533'},
#    {'rank': 0,
#     'subtype': 'blog427',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-blog427.jpg',
#     'height': 285,
#     'width': 427,
#     'legacy': {},
#     'subType': 'blog427',
#     'crop_name': 'blog427'},
#    {'rank': 0,
#     'subtype': 'tmagSF',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-tmagSF.jpg',
#     'height': 241,
#     'width': 362,
#     'legacy': {},
#     'subType': 'tmagSF',
#     'crop_name': 'tmagSF'},
#    {'rank': 0,
#     'subtype': 'tmagArticle',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-tmagArticle.jpg',
#     'height': 395,
#     'width': 592,
#     'legacy': {},
#     'subType': 'tmagArticle',
#     'crop_name': 'tmagArticle'},
#    {'rank': 0,
#     'subtype': 'slide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-slide.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {},
#     'subType': 'slide',
#     'crop_name': 'slide'},
#    {'rank': 0,
#     'subtype': 'jumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-jumbo.jpg',
#     'height': 683,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'jumbo',
#     'crop_name': 'jumbo'},
#    {'rank': 0,
#     'subtype': 'superJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-superJumbo.jpg',
#     'height': 1365,
#     'width': 2048,
#     'legacy': {},
#     'subType': 'superJumbo',
#     'crop_name': 'superJumbo'},
#    {'rank': 0,
#     'subtype': 'blog225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-blog225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'blog225',
#     'crop_name': 'blog225'},
#    {'rank': 0,
#     'subtype': 'master1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-master1050.jpg',
#     'height': 700,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'master1050',
#     'crop_name': 'master1050'},
#    {'rank': 0,
#     'subtype': 'master675',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-master675.jpg',
#     'height': 450,
#     'width': 675,
#     'legacy': {},
#     'subType': 'master675',
#     'crop_name': 'master675'},
#    {'rank': 0,
#     'subtype': 'master495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-master495.jpg',
#     'height': 330,
#     'width': 495,
#     'legacy': {},
#     'subType': 'master495',
#     'crop_name': 'master495'},
#    {'rank': 0,
#     'subtype': 'master180',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-master180.jpg',
#     'height': 120,
#     'width': 180,
#     'legacy': {},
#     'subType': 'master180',
#     'crop_name': 'master180'},
#    {'rank': 0,
#     'subtype': 'master315',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-master315.jpg',
#     'height': 210,
#     'width': 315,
#     'legacy': {},
#     'subType': 'master315',
#     'crop_name': 'master315'},
#    {'rank': 0,
#     'subtype': 'master768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-master768.jpg',
#     'height': 512,
#     'width': 768,
#     'legacy': {},
#     'subType': 'master768',
#     'crop_name': 'master768'},
#    {'rank': 0,
#     'subtype': 'thumbnail',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-thumbStandard.jpg',
#     'height': 75,
#     'width': 75,
#     'legacy': {'thumbnail': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-thumbStandard.jpg',
#      'thumbnailwidth': 75,
#      'thumbnailheight': 75},
#     'subType': 'thumbnail',
#     'crop_name': 'thumbStandard'},
#    {'rank': 0,
#     'subtype': 'blogSmallThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-blogSmallThumb.jpg',
#     'height': 50,
#     'width': 50,
#     'legacy': {},
#     'subType': 'blogSmallThumb',
#     'crop_name': 'blogSmallThumb'},
#    {'rank': 0,
#     'subtype': 'thumbLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-thumbLarge.jpg',
#     'height': 150,
#     'width': 150,
#     'legacy': {},
#     'subType': 'thumbLarge',
#     'crop_name': 'thumbLarge'},
#    {'rank': 0,
#     'subtype': 'smallSquare168',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-smallSquare168.jpg',
#     'height': 168,
#     'width': 168,
#     'legacy': {},
#     'subType': 'smallSquare168',
#     'crop_name': 'smallSquare168'},
#    {'rank': 0,
#     'subtype': 'smallSquare252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-smallSquare252.jpg',
#     'height': 252,
#     'width': 252,
#     'legacy': {},
#     'subType': 'smallSquare252',
#     'crop_name': 'smallSquare252'},
#    {'rank': 0,
#     'subtype': 'square320',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-square320.jpg',
#     'height': 320,
#     'width': 320,
#     'legacy': {},
#     'subType': 'square320',
#     'crop_name': 'square320'},
#    {'rank': 0,
#     'subtype': 'moth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-moth.jpg',
#     'height': 151,
#     'width': 151,
#     'legacy': {},
#     'subType': 'moth',
#     'crop_name': 'moth'},
#    {'rank': 0,
#     'subtype': 'filmstrip',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-filmstrip.jpg',
#     'height': 190,
#     'width': 190,
#     'legacy': {},
#     'subType': 'filmstrip',
#     'crop_name': 'filmstrip'},
#    {'rank': 0,
#     'subtype': 'square640',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-square640.jpg',
#     'height': 640,
#     'width': 640,
#     'legacy': {},
#     'subType': 'square640',
#     'crop_name': 'square640'},
#    {'rank': 0,
#     'subtype': 'mediumSquare149',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-mediumSquare149.jpg',
#     'height': 149,
#     'width': 149,
#     'legacy': {},
#     'subType': 'mediumSquare149',
#     'crop_name': 'mediumSquare149'},
#    {'rank': 0,
#     'subtype': 'mediumSquareAt3X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-mediumSquareAt3X.jpg',
#     'height': 1800,
#     'width': 1800,
#     'legacy': {},
#     'subType': 'mediumSquareAt3X',
#     'crop_name': 'mediumSquareAt3X'},
#    {'rank': 0,
#     'subtype': 'sfSpan',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-sfSpan.jpg',
#     'height': 263,
#     'width': 395,
#     'legacy': {},
#     'subType': 'sfSpan',
#     'crop_name': 'sfSpan'},
#    {'rank': 0,
#     'subtype': 'largeHorizontal375',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-largeHorizontal375.jpg',
#     'height': 250,
#     'width': 375,
#     'legacy': {},
#     'subType': 'largeHorizontal375',
#     'crop_name': 'largeHorizontal375'},
#    {'rank': 0,
#     'subtype': 'largeHorizontalJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-largeHorizontalJumbo.jpg',
#     'height': 683,
#     'width': 1024,
#     'legacy': {},
#     'subType': 'largeHorizontalJumbo',
#     'crop_name': 'largeHorizontalJumbo'},
#    {'rank': 0,
#     'subtype': 'horizontalMediumAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-horizontalMediumAt2X.jpg',
#     'height': 5360,
#     'width': 8040,
#     'legacy': {},
#     'subType': 'horizontalMediumAt2X',
#     'crop_name': 'horizontalMediumAt2X'},
#    {'rank': 0,
#     'subtype': 'hpLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-hpLarge.jpg',
#     'height': 287,
#     'width': 511,
#     'legacy': {},
#     'subType': 'hpLarge',
#     'crop_name': 'hpLarge'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen573',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-largeWidescreen573.jpg',
#     'height': 322,
#     'width': 573,
#     'legacy': {},
#     'subType': 'largeWidescreen573',
#     'crop_name': 'largeWidescreen573'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-largeWidescreen1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'largeWidescreen1050',
#     'crop_name': 'largeWidescreen1050'},
#    {'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'widewidth': 190,
#      'wideheight': 126,
#      'wide': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-thumbWide.jpg'},
#     'subType': 'wide',
#     'crop_name': 'thumbWide'},
#    {'rank': 0,
#     'subtype': 'videoThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-videoThumb.jpg',
#     'height': 50,
#     'width': 75,
#     'legacy': {},
#     'subType': 'videoThumb',
#     'crop_name': 'videoThumb'},
#    {'rank': 0,
#     'subtype': 'videoLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-videoLarge.jpg',
#     'height': 507,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoLarge',
#     'crop_name': 'videoLarge'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo210',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-mediumThreeByTwo210.jpg',
#     'height': 140,
#     'width': 210,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo210',
#     'crop_name': 'mediumThreeByTwo210'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-mediumThreeByTwo225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo225',
#     'crop_name': 'mediumThreeByTwo225'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo440',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-mediumThreeByTwo440.jpg',
#     'height': 293,
#     'width': 440,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo440',
#     'crop_name': 'mediumThreeByTwo440'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-mediumThreeByTwo252.jpg',
#     'height': 168,
#     'width': 252,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo252',
#     'crop_name': 'mediumThreeByTwo252'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo378',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-mediumThreeByTwo378.jpg',
#     'height': 252,
#     'width': 378,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo378',
#     'crop_name': 'mediumThreeByTwo378'},
#    {'rank': 0,
#     'subtype': 'threeByTwoLargeAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-threeByTwoLargeAt2X.jpg',
#     'height': 5360,
#     'width': 8040,
#     'legacy': {},
#     'subType': 'threeByTwoLargeAt2X',
#     'crop_name': 'threeByTwoLargeAt2X'},
#    {'rank': 0,
#     'subtype': 'threeByTwoMediumAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-threeByTwoMediumAt2X.jpg',
#     'height': 1000,
#     'width': 1500,
#     'legacy': {},
#     'subType': 'threeByTwoMediumAt2X',
#     'crop_name': 'threeByTwoMediumAt2X'},
#    {'rank': 0,
#     'subtype': 'threeByTwoSmallAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-threeByTwoSmallAt2X.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {},
#     'subType': 'threeByTwoSmallAt2X',
#     'crop_name': 'threeByTwoSmallAt2X'},
#    {'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-articleInline.jpg',
#     'height': 127,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'hpSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-hpSmall.jpg',
#     'height': 109,
#     'width': 163,
#     'legacy': {},
#     'subType': 'hpSmall',
#     'crop_name': 'hpSmall'},
#    {'rank': 0,
#     'subtype': 'blogSmallInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-blogSmallInline.jpg',
#     'height': 101,
#     'width': 151,
#     'legacy': {},
#     'subType': 'blogSmallInline',
#     'crop_name': 'blogSmallInline'},
#    {'rank': 0,
#     'subtype': 'mediumFlexible177',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-mediumFlexible177.jpg',
#     'height': 118,
#     'width': 177,
#     'legacy': {},
#     'subType': 'mediumFlexible177',
#     'crop_name': 'mediumFlexible177'},
#    {'rank': 0,
#     'subtype': 'videoSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-videoSmall.jpg',
#     'height': 281,
#     'width': 500,
#     'legacy': {},
#     'subType': 'videoSmall',
#     'crop_name': 'videoSmall'},
#    {'rank': 0,
#     'subtype': 'videoHpMedium',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-videoHpMedium.jpg',
#     'height': 211,
#     'width': 375,
#     'legacy': {},
#     'subType': 'videoHpMedium',
#     'crop_name': 'videoHpMedium'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-videoSixteenByNine600.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {},
#     'subType': 'videoSixteenByNine600',
#     'crop_name': 'videoSixteenByNine600'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine540',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/28/sports/28wcbb-clark-01/merlin_202840398_63163f61-6982-4fe1-a257-4e143b9b49c1-videoSixteenByNine540.jpg',
# ...
#     'height': 1976,
#     'width': 2967,
#     'legacy': {},
#     'subType': 'horizontalMediumAt2X',
#     'crop_name': 'horizontalMediumAt2X'},
#    {'rank': 0,
#     'subtype': 'hpLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-hpLarge.jpg',
#     'height': 287,
#     'width': 511,
#     'legacy': {},
#     'subType': 'hpLarge',
#     'crop_name': 'hpLarge'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen573',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-largeWidescreen573.jpg',
#     'height': 322,
#     'width': 573,
#     'legacy': {},
#     'subType': 'largeWidescreen573',
#     'crop_name': 'largeWidescreen573'},
#    {'rank': 0,
#     'subtype': 'largeWidescreen1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-largeWidescreen1050.jpg',
#     'height': 590,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'largeWidescreen1050',
#     'crop_name': 'largeWidescreen1050'},
#    {'rank': 0,
#     'subtype': 'wide',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-thumbWide.jpg',
#     'height': 126,
#     'width': 190,
#     'legacy': {'widewidth': 190,
#      'wideheight': 126,
#      'wide': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-thumbWide.jpg'},
#     'subType': 'wide',
#     'crop_name': 'thumbWide'},
#    {'rank': 0,
#     'subtype': 'videoThumb',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-videoThumb.jpg',
#     'height': 50,
#     'width': 75,
#     'legacy': {},
#     'subType': 'videoThumb',
#     'crop_name': 'videoThumb'},
#    {'rank': 0,
#     'subtype': 'videoLarge',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-videoLarge.jpg',
#     'height': 507,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoLarge',
#     'crop_name': 'videoLarge'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo210',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-mediumThreeByTwo210.jpg',
#     'height': 140,
#     'width': 210,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo210',
#     'crop_name': 'mediumThreeByTwo210'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-mediumThreeByTwo225.jpg',
#     'height': 150,
#     'width': 225,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo225',
#     'crop_name': 'mediumThreeByTwo225'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo440',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-mediumThreeByTwo440.jpg',
#     'height': 293,
#     'width': 440,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo440',
#     'crop_name': 'mediumThreeByTwo440'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo252',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-mediumThreeByTwo252.jpg',
#     'height': 168,
#     'width': 252,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo252',
#     'crop_name': 'mediumThreeByTwo252'},
#    {'rank': 0,
#     'subtype': 'mediumThreeByTwo378',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-mediumThreeByTwo378.jpg',
#     'height': 252,
#     'width': 378,
#     'legacy': {},
#     'subType': 'mediumThreeByTwo378',
#     'crop_name': 'mediumThreeByTwo378'},
#    {'rank': 0,
#     'subtype': 'threeByTwoLargeAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-threeByTwoLargeAt2X.jpg',
#     'height': 1976,
#     'width': 2967,
#     'legacy': {},
#     'subType': 'threeByTwoLargeAt2X',
#     'crop_name': 'threeByTwoLargeAt2X'},
#    {'rank': 0,
#     'subtype': 'threeByTwoMediumAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-threeByTwoMediumAt2X.jpg',
#     'height': 999,
#     'width': 1500,
#     'legacy': {},
#     'subType': 'threeByTwoMediumAt2X',
#     'crop_name': 'threeByTwoMediumAt2X'},
#    {'rank': 0,
#     'subtype': 'threeByTwoSmallAt2X',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-threeByTwoSmallAt2X.jpg',
#     'height': 400,
#     'width': 600,
#     'legacy': {},
#     'subType': 'threeByTwoSmallAt2X',
#     'crop_name': 'threeByTwoSmallAt2X'},
#    {'rank': 0,
#     'subtype': 'articleInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-articleInline.jpg',
#     'height': 125,
#     'width': 190,
#     'legacy': {},
#     'subType': 'articleInline',
#     'crop_name': 'articleInline'},
#    {'rank': 0,
#     'subtype': 'hpSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-hpSmall.jpg',
#     'height': 107,
#     'width': 163,
#     'legacy': {},
#     'subType': 'hpSmall',
#     'crop_name': 'hpSmall'},
#    {'rank': 0,
#     'subtype': 'blogSmallInline',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-blogSmallInline.jpg',
#     'height': 99,
#     'width': 151,
#     'legacy': {},
#     'subType': 'blogSmallInline',
#     'crop_name': 'blogSmallInline'},
#    {'rank': 0,
#     'subtype': 'mediumFlexible177',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-mediumFlexible177.jpg',
#     'height': 116,
#     'width': 177,
#     'legacy': {},
#     'subType': 'mediumFlexible177',
#     'crop_name': 'mediumFlexible177'},
#    {'rank': 0,
#     'subtype': 'videoSmall',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-videoSmall.jpg',
#     'height': 281,
#     'width': 500,
#     'legacy': {},
#     'subType': 'videoSmall',
#     'crop_name': 'videoSmall'},
#    {'rank': 0,
#     'subtype': 'videoHpMedium',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-videoHpMedium.jpg',
#     'height': 211,
#     'width': 375,
#     'legacy': {},
#     'subType': 'videoHpMedium',
#     'crop_name': 'videoHpMedium'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-videoSixteenByNine600.jpg',
#     'height': 338,
#     'width': 600,
#     'legacy': {},
#     'subType': 'videoSixteenByNine600',
#     'crop_name': 'videoSixteenByNine600'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine540',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-videoSixteenByNine540.jpg',
#     'height': 304,
#     'width': 540,
#     'legacy': {},
#     'subType': 'videoSixteenByNine540',
#     'crop_name': 'videoSixteenByNine540'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine495',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-videoSixteenByNine495.jpg',
#     'height': 278,
#     'width': 495,
#     'legacy': {},
#     'subType': 'videoSixteenByNine495',
#     'crop_name': 'videoSixteenByNine495'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine390',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-videoSixteenByNine390.jpg',
#     'height': 219,
#     'width': 390,
#     'legacy': {},
#     'subType': 'videoSixteenByNine390',
#     'crop_name': 'videoSixteenByNine390'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine1050',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-videoSixteenByNine1050.jpg',
#     'height': 591,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'videoSixteenByNine1050',
#     'crop_name': 'videoSixteenByNine1050'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine480',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-videoSixteenByNine480.jpg',
#     'height': 270,
#     'width': 480,
#     'legacy': {},
#     'subType': 'videoSixteenByNine480',
#     'crop_name': 'videoSixteenByNine480'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine310',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-videoSixteenByNine310.jpg',
#     'height': 174,
#     'width': 310,
#     'legacy': {},
#     'subType': 'videoSixteenByNine310',
#     'crop_name': 'videoSixteenByNine310'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine225',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-videoSixteenByNine225.jpg',
#     'height': 126,
#     'width': 225,
#     'legacy': {},
#     'subType': 'videoSixteenByNine225',
#     'crop_name': 'videoSixteenByNine225'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine96',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-videoSixteenByNine96.jpg',
#     'height': 54,
#     'width': 96,
#     'legacy': {},
#     'subType': 'videoSixteenByNine96',
#     'crop_name': 'videoSixteenByNine96'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine3000',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-videoSixteenByNine3000.jpg',
#     'height': 1686,
#     'width': 3000,
#     'legacy': {},
#     'subType': 'videoSixteenByNine3000',
#     'crop_name': 'videoSixteenByNine3000'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine768',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-videoSixteenByNine768.jpg',
#     'height': 432,
#     'width': 768,
#     'legacy': {},
#     'subType': 'videoSixteenByNine768',
#     'crop_name': 'videoSixteenByNine768'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNine150',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-videoSixteenByNine150.jpg',
#     'height': 84,
#     'width': 150,
#     'legacy': {},
#     'subType': 'videoSixteenByNine150',
#     'crop_name': 'videoSixteenByNine150'},
#    {'rank': 0,
#     'subtype': 'videoSixteenByNineJumbo1600',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-videoSixteenByNineJumbo1600.jpg',
#     'height': 899,
#     'width': 1600,
#     'legacy': {},
#     'subType': 'videoSixteenByNineJumbo1600',
#     'crop_name': 'videoSixteenByNineJumbo1600'},
#    {'rank': 0,
#     'subtype': 'miniMoth',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-miniMoth.jpg',
#     'height': 70,
#     'width': 151,
#     'legacy': {},
#     'subType': 'miniMoth',
#     'crop_name': 'miniMoth'},
#    {'rank': 0,
#     'subtype': 'windowsTile336H',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-windowsTile336H.jpg',
#     'height': 336,
#     'width': 694,
#     'legacy': {},
#     'subType': 'windowsTile336H',
#     'crop_name': 'windowsTile336H'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven1305',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-videoFifteenBySeven1305.jpg',
#     'height': 609,
#     'width': 1305,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven1305',
#     'crop_name': 'videoFifteenBySeven1305'},
#    {'rank': 0,
#     'subtype': 'videoFifteenBySeven2610',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-videoFifteenBySeven2610.jpg',
#     'height': 1218,
#     'width': 2610,
#     'legacy': {},
#     'subType': 'videoFifteenBySeven2610',
#     'crop_name': 'videoFifteenBySeven2610'},
#    {'rank': 0,
#     'subtype': 'facebookJumbo',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-facebookJumbo.jpg',
#     'height': 549,
#     'width': 1050,
#     'legacy': {},
#     'subType': 'facebookJumbo',
#     'crop_name': 'facebookJumbo'},
#    {'rank': 0,
#     'subtype': 'watch308',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-watch308.jpg',
#     'height': 348,
#     'width': 312,
#     'legacy': {},
#     'subType': 'watch308',
#     'crop_name': 'watch308'},
#    {'rank': 0,
#     'subtype': 'watch268',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-watch268.jpg',
#     'height': 303,
#     'width': 272,
#     'legacy': {},
#     'subType': 'watch268',
#     'crop_name': 'watch268'},
#    {'rank': 0,
#     'subtype': 'verticalTwoByThree735',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-verticalTwoByThree735.jpg',
#     'height': 1101,
#     'width': 735,
#     'legacy': {},
#     'subType': 'verticalTwoByThree735',
#     'crop_name': 'verticalTwoByThree735'},
#    {'rank': 0,
#     'subtype': 'mobileMasterAt3x',
#     'caption': None,
#     'credit': None,
#     'type': 'image',
#     'url': 'images/2022/02/04/obituaries/03Fitch1-print1/03Fitch1-mobileMasterAt3x.jpg',
#     'height': 1181,
#     'width': 1800,
#     'legacy': {},
#     'subType': 'mobileMasterAt3x',
#     'crop_name': 'mobileMasterAt3x'}],
#   'headline': {'main': 'Bill Fitch, Who Coached Celtics to the ’81 Title, Is Dead at 89',
#    'kicker': None,
#    'content_kicker': None,
#    'print_headline': 'Bill Fitch, 89, Who Coached Celtics to ’81 Title, Dies',
#    'name': None,
#    'seo': None,
#    'sub': None},
#   'keywords': [{'name': 'subject',
#     'value': 'Basketball',
#     'rank': 1,
#     'major': 'N'},
#    {'name': 'subject', 'value': 'NBA Championship', 'rank': 2, 'major': 'N'},
#    {'name': 'subject',
#     'value': 'Coaches and Managers',
#     'rank': 3,
#     'major': 'N'},
#    {'name': 'subject',
#     'value': 'Deaths (Obituaries)',
#     'rank': 4,
#     'major': 'N'},
#    {'name': 'persons', 'value': 'Fitch, Bill', 'rank': 5, 'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Boston Celtics',
#     'rank': 6,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Houston Rockets',
#     'rank': 7,
#     'major': 'N'},
#    {'name': 'organizations',
#     'value': 'Cleveland Cavaliers',
#     'rank': 8,
#     'major': 'N'}],
#   'pub_date': datetime.datetime(2022, 2, 3, 17, 57, 10, tzinfo=datetime.timezone.utc),
#   'document_type': 'article',
#   'news_desk': 'Obits',
#   'section_name': 'Sports',
#   'subsection_name': 'Pro Basketball',
#   'byline': {'original': 'By Richard Goldstein',
#    'person': [{'firstname': 'Richard',
#      'middlename': None,
#      'lastname': 'Goldstein',
#      'qualifier': None,
#      'title': None,
#      'role': 'reported',
#      'organization': '',
#      'rank': 1}],
#    'organization': None},
#   'type_of_material': 'Obituary (Obit)',
#   '_id': 'nyt://article/2391f273-ed97-5cf0-9edd-8815732ac948',
#   'word_count': 914,
#   'uri': 'nyt://article/2391f273-ed97-5cf0-9edd-8815732ac948'}]

# %%
len(results)
# Out:
# 30

# %%
## Let's look at one
results[0]
# Out:
# {'abstract': 'Seven of the top 10 teams lost in a single day, setting off fan celebrations and reinforcing the notion that the N.C.A.A. tournament will be wide open.',
#  'web_url': 'https://www.nytimes.com/2022/02/27/sports/ncaabasketball/ncaa-top-10-mens-college-basketball.html',
#  'snippet': 'Seven of the top 10 teams lost in a single day, setting off fan celebrations and reinforcing the notion that the N.C.A.A. tournament will be wide open.',
#  'lead_paragraph': 'The calendar won’t flip to March until Tuesday, but Saturday featured a full menu of madness in men’s college basketball.',
#  'print_section': 'D',
#  'print_page': '3',
#  'source': 'The New York Times',
#  'multimedia': [{'rank': 0,
#    'subtype': 'xlarge',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-articleLarge.jpg',
#    'height': 400,
#    'width': 600,
#    'legacy': {'xlarge': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-articleLarge.jpg',
#     'xlargewidth': 600,
#     'xlargeheight': 400},
#    'subType': 'xlarge',
#    'crop_name': 'articleLarge'},
#   {'rank': 0,
#    'subtype': 'popup',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-popup.jpg',
#    'height': 433,
#    'width': 650,
#    'legacy': {},
#    'subType': 'popup',
#    'crop_name': 'popup'},
#   {'rank': 0,
#    'subtype': 'blog480',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-blog480.jpg',
#    'height': 320,
#    'width': 480,
#    'legacy': {},
#    'subType': 'blog480',
#    'crop_name': 'blog480'},
#   {'rank': 0,
#    'subtype': 'blog533',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-blog533.jpg',
#    'height': 355,
#    'width': 533,
#    'legacy': {},
#    'subType': 'blog533',
#    'crop_name': 'blog533'},
#   {'rank': 0,
#    'subtype': 'blog427',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-blog427.jpg',
#    'height': 285,
#    'width': 427,
#    'legacy': {},
#    'subType': 'blog427',
#    'crop_name': 'blog427'},
#   {'rank': 0,
#    'subtype': 'tmagSF',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-tmagSF.jpg',
#    'height': 241,
#    'width': 362,
#    'legacy': {},
#    'subType': 'tmagSF',
#    'crop_name': 'tmagSF'},
#   {'rank': 0,
#    'subtype': 'tmagArticle',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-tmagArticle.jpg',
#    'height': 395,
#    'width': 592,
#    'legacy': {},
#    'subType': 'tmagArticle',
#    'crop_name': 'tmagArticle'},
#   {'rank': 0,
#    'subtype': 'slide',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-slide.jpg',
#    'height': 400,
#    'width': 600,
#    'legacy': {},
#    'subType': 'slide',
#    'crop_name': 'slide'},
#   {'rank': 0,
#    'subtype': 'jumbo',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-jumbo.jpg',
#    'height': 683,
#    'width': 1024,
#    'legacy': {},
#    'subType': 'jumbo',
#    'crop_name': 'jumbo'},
#   {'rank': 0,
#    'subtype': 'superJumbo',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-superJumbo.jpg',
#    'height': 1365,
#    'width': 2048,
#    'legacy': {},
#    'subType': 'superJumbo',
#    'crop_name': 'superJumbo'},
#   {'rank': 0,
#    'subtype': 'blog225',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-blog225.jpg',
#    'height': 150,
#    'width': 225,
#    'legacy': {},
#    'subType': 'blog225',
#    'crop_name': 'blog225'},
#   {'rank': 0,
#    'subtype': 'master1050',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-master1050.jpg',
#    'height': 700,
#    'width': 1050,
#    'legacy': {},
#    'subType': 'master1050',
#    'crop_name': 'master1050'},
#   {'rank': 0,
#    'subtype': 'master675',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-master675.jpg',
#    'height': 450,
#    'width': 675,
#    'legacy': {},
#    'subType': 'master675',
#    'crop_name': 'master675'},
#   {'rank': 0,
#    'subtype': 'master495',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-master495.jpg',
#    'height': 330,
#    'width': 495,
#    'legacy': {},
#    'subType': 'master495',
#    'crop_name': 'master495'},
#   {'rank': 0,
#    'subtype': 'master180',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-master180.jpg',
#    'height': 120,
#    'width': 180,
#    'legacy': {},
#    'subType': 'master180',
#    'crop_name': 'master180'},
#   {'rank': 0,
#    'subtype': 'master315',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-master315.jpg',
#    'height': 210,
#    'width': 315,
#    'legacy': {},
#    'subType': 'master315',
#    'crop_name': 'master315'},
#   {'rank': 0,
#    'subtype': 'master768',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-master768.jpg',
#    'height': 512,
#    'width': 768,
#    'legacy': {},
#    'subType': 'master768',
#    'crop_name': 'master768'},
#   {'rank': 0,
#    'subtype': 'thumbnail',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-thumbStandard.jpg',
#    'height': 75,
#    'width': 75,
#    'legacy': {'thumbnail': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-thumbStandard.jpg',
#     'thumbnailwidth': 75,
#     'thumbnailheight': 75},
#    'subType': 'thumbnail',
#    'crop_name': 'thumbStandard'},
#   {'rank': 0,
#    'subtype': 'blogSmallThumb',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-blogSmallThumb.jpg',
#    'height': 50,
#    'width': 50,
#    'legacy': {},
#    'subType': 'blogSmallThumb',
#    'crop_name': 'blogSmallThumb'},
#   {'rank': 0,
#    'subtype': 'thumbLarge',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-thumbLarge.jpg',
#    'height': 150,
#    'width': 150,
#    'legacy': {},
#    'subType': 'thumbLarge',
#    'crop_name': 'thumbLarge'},
#   {'rank': 0,
#    'subtype': 'smallSquare168',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-smallSquare168.jpg',
#    'height': 168,
#    'width': 168,
#    'legacy': {},
#    'subType': 'smallSquare168',
#    'crop_name': 'smallSquare168'},
#   {'rank': 0,
#    'subtype': 'smallSquare252',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-smallSquare252.jpg',
#    'height': 252,
#    'width': 252,
#    'legacy': {},
#    'subType': 'smallSquare252',
#    'crop_name': 'smallSquare252'},
#   {'rank': 0,
#    'subtype': 'square320',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-square320.jpg',
#    'height': 320,
#    'width': 320,
#    'legacy': {},
#    'subType': 'square320',
#    'crop_name': 'square320'},
#   {'rank': 0,
#    'subtype': 'moth',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-moth.jpg',
#    'height': 151,
#    'width': 151,
#    'legacy': {},
#    'subType': 'moth',
#    'crop_name': 'moth'},
#   {'rank': 0,
#    'subtype': 'filmstrip',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-filmstrip.jpg',
#    'height': 190,
#    'width': 190,
#    'legacy': {},
#    'subType': 'filmstrip',
#    'crop_name': 'filmstrip'},
#   {'rank': 0,
#    'subtype': 'square640',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-square640.jpg',
#    'height': 640,
#    'width': 640,
#    'legacy': {},
#    'subType': 'square640',
#    'crop_name': 'square640'},
#   {'rank': 0,
#    'subtype': 'mediumSquare149',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-mediumSquare149.jpg',
#    'height': 149,
#    'width': 149,
#    'legacy': {},
#    'subType': 'mediumSquare149',
#    'crop_name': 'mediumSquare149'},
#   {'rank': 0,
#    'subtype': 'mediumSquareAt3X',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-mediumSquareAt3X.jpg',
#    'height': 1800,
#    'width': 1800,
#    'legacy': {},
#    'subType': 'mediumSquareAt3X',
#    'crop_name': 'mediumSquareAt3X'},
#   {'rank': 0,
#    'subtype': 'sfSpan',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-sfSpan.jpg',
#    'height': 263,
#    'width': 395,
#    'legacy': {},
#    'subType': 'sfSpan',
#    'crop_name': 'sfSpan'},
#   {'rank': 0,
#    'subtype': 'largeHorizontal375',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-largeHorizontal375.jpg',
#    'height': 250,
#    'width': 375,
#    'legacy': {},
#    'subType': 'largeHorizontal375',
#    'crop_name': 'largeHorizontal375'},
#   {'rank': 0,
#    'subtype': 'largeHorizontalJumbo',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-largeHorizontalJumbo.jpg',
#    'height': 683,
#    'width': 1024,
#    'legacy': {},
#    'subType': 'largeHorizontalJumbo',
#    'crop_name': 'largeHorizontalJumbo'},
#   {'rank': 0,
#    'subtype': 'horizontalMediumAt2X',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-horizontalMediumAt2X.jpg',
#    'height': 4471,
#    'width': 6707,
#    'legacy': {},
#    'subType': 'horizontalMediumAt2X',
#    'crop_name': 'horizontalMediumAt2X'},
#   {'rank': 0,
#    'subtype': 'hpLarge',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-hpLarge.jpg',
#    'height': 287,
#    'width': 511,
#    'legacy': {},
#    'subType': 'hpLarge',
#    'crop_name': 'hpLarge'},
#   {'rank': 0,
#    'subtype': 'largeWidescreen573',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-largeWidescreen573.jpg',
#    'height': 322,
#    'width': 573,
#    'legacy': {},
#    'subType': 'largeWidescreen573',
#    'crop_name': 'largeWidescreen573'},
#   {'rank': 0,
#    'subtype': 'largeWidescreen1050',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-largeWidescreen1050.jpg',
#    'height': 591,
#    'width': 1050,
#    'legacy': {},
#    'subType': 'largeWidescreen1050',
#    'crop_name': 'largeWidescreen1050'},
#   {'rank': 0,
#    'subtype': 'wide',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-thumbWide.jpg',
#    'height': 126,
#    'width': 190,
#    'legacy': {'widewidth': 190,
#     'wideheight': 126,
#     'wide': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-thumbWide.jpg'},
#    'subType': 'wide',
#    'crop_name': 'thumbWide'},
#   {'rank': 0,
#    'subtype': 'videoThumb',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoThumb.jpg',
#    'height': 50,
#    'width': 75,
#    'legacy': {},
#    'subType': 'videoThumb',
#    'crop_name': 'videoThumb'},
#   {'rank': 0,
#    'subtype': 'videoLarge',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoLarge.jpg',
#    'height': 507,
#    'width': 768,
#    'legacy': {},
#    'subType': 'videoLarge',
#    'crop_name': 'videoLarge'},
#   {'rank': 0,
#    'subtype': 'mediumThreeByTwo210',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-mediumThreeByTwo210.jpg',
#    'height': 140,
#    'width': 210,
#    'legacy': {},
#    'subType': 'mediumThreeByTwo210',
#    'crop_name': 'mediumThreeByTwo210'},
#   {'rank': 0,
#    'subtype': 'mediumThreeByTwo225',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-mediumThreeByTwo225.jpg',
#    'height': 150,
#    'width': 225,
#    'legacy': {},
#    'subType': 'mediumThreeByTwo225',
#    'crop_name': 'mediumThreeByTwo225'},
#   {'rank': 0,
#    'subtype': 'mediumThreeByTwo440',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-mediumThreeByTwo440.jpg',
#    'height': 293,
#    'width': 440,
#    'legacy': {},
#    'subType': 'mediumThreeByTwo440',
#    'crop_name': 'mediumThreeByTwo440'},
#   {'rank': 0,
#    'subtype': 'mediumThreeByTwo252',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-mediumThreeByTwo252.jpg',
#    'height': 168,
#    'width': 252,
#    'legacy': {},
#    'subType': 'mediumThreeByTwo252',
#    'crop_name': 'mediumThreeByTwo252'},
#   {'rank': 0,
#    'subtype': 'mediumThreeByTwo378',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-mediumThreeByTwo378.jpg',
#    'height': 252,
#    'width': 378,
#    'legacy': {},
#    'subType': 'mediumThreeByTwo378',
#    'crop_name': 'mediumThreeByTwo378'},
#   {'rank': 0,
#    'subtype': 'threeByTwoLargeAt2X',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-threeByTwoLargeAt2X.jpg',
#    'height': 4471,
#    'width': 6707,
#    'legacy': {},
#    'subType': 'threeByTwoLargeAt2X',
#    'crop_name': 'threeByTwoLargeAt2X'},
#   {'rank': 0,
#    'subtype': 'threeByTwoMediumAt2X',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-threeByTwoMediumAt2X.jpg',
#    'height': 1000,
#    'width': 1500,
#    'legacy': {},
#    'subType': 'threeByTwoMediumAt2X',
#    'crop_name': 'threeByTwoMediumAt2X'},
#   {'rank': 0,
#    'subtype': 'threeByTwoSmallAt2X',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-threeByTwoSmallAt2X.jpg',
#    'height': 400,
#    'width': 600,
#    'legacy': {},
#    'subType': 'threeByTwoSmallAt2X',
#    'crop_name': 'threeByTwoSmallAt2X'},
#   {'rank': 0,
#    'subtype': 'articleInline',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-articleInline.jpg',
#    'height': 127,
#    'width': 190,
#    'legacy': {},
#    'subType': 'articleInline',
#    'crop_name': 'articleInline'},
#   {'rank': 0,
#    'subtype': 'hpSmall',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-hpSmall.jpg',
#    'height': 109,
#    'width': 163,
#    'legacy': {},
#    'subType': 'hpSmall',
#    'crop_name': 'hpSmall'},
#   {'rank': 0,
#    'subtype': 'blogSmallInline',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-blogSmallInline.jpg',
#    'height': 101,
#    'width': 151,
#    'legacy': {},
#    'subType': 'blogSmallInline',
#    'crop_name': 'blogSmallInline'},
#   {'rank': 0,
#    'subtype': 'mediumFlexible177',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-mediumFlexible177.jpg',
#    'height': 118,
#    'width': 177,
#    'legacy': {},
#    'subType': 'mediumFlexible177',
#    'crop_name': 'mediumFlexible177'},
#   {'rank': 0,
#    'subtype': 'videoSmall',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSmall.jpg',
#    'height': 281,
#    'width': 500,
#    'legacy': {},
#    'subType': 'videoSmall',
#    'crop_name': 'videoSmall'},
#   {'rank': 0,
#    'subtype': 'videoHpMedium',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoHpMedium.jpg',
#    'height': 211,
#    'width': 375,
#    'legacy': {},
#    'subType': 'videoHpMedium',
#    'crop_name': 'videoHpMedium'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine600',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine600.jpg',
#    'height': 338,
#    'width': 600,
#    'legacy': {},
#    'subType': 'videoSixteenByNine600',
#    'crop_name': 'videoSixteenByNine600'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine540',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine540.jpg',
#    'height': 304,
#    'width': 540,
#    'legacy': {},
#    'subType': 'videoSixteenByNine540',
#    'crop_name': 'videoSixteenByNine540'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine495',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine495.jpg',
#    'height': 278,
#    'width': 495,
#    'legacy': {},
#    'subType': 'videoSixteenByNine495',
#    'crop_name': 'videoSixteenByNine495'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine390',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine390.jpg',
#    'height': 219,
#    'width': 390,
#    'legacy': {},
#    'subType': 'videoSixteenByNine390',
#    'crop_name': 'videoSixteenByNine390'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine1050',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine1050.jpg',
#    'height': 591,
#    'width': 1050,
#    'legacy': {},
#    'subType': 'videoSixteenByNine1050',
#    'crop_name': 'videoSixteenByNine1050'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine480',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine480.jpg',
#    'height': 270,
#    'width': 480,
#    'legacy': {},
#    'subType': 'videoSixteenByNine480',
#    'crop_name': 'videoSixteenByNine480'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine310',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine310.jpg',
#    'height': 174,
#    'width': 310,
#    'legacy': {},
#    'subType': 'videoSixteenByNine310',
#    'crop_name': 'videoSixteenByNine310'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine225',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine225.jpg',
#    'height': 126,
#    'width': 225,
#    'legacy': {},
#    'subType': 'videoSixteenByNine225',
#    'crop_name': 'videoSixteenByNine225'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine96',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine96.jpg',
#    'height': 54,
#    'width': 96,
#    'legacy': {},
#    'subType': 'videoSixteenByNine96',
#    'crop_name': 'videoSixteenByNine96'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine3000',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine3000.jpg',
#    'height': 1688,
#    'width': 3000,
#    'legacy': {},
#    'subType': 'videoSixteenByNine3000',
#    'crop_name': 'videoSixteenByNine3000'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine768',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine768.jpg',
#    'height': 432,
#    'width': 768,
#    'legacy': {},
#    'subType': 'videoSixteenByNine768',
#    'crop_name': 'videoSixteenByNine768'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNine150',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNine150.jpg',
#    'height': 84,
#    'width': 150,
#    'legacy': {},
#    'subType': 'videoSixteenByNine150',
#    'crop_name': 'videoSixteenByNine150'},
#   {'rank': 0,
#    'subtype': 'videoSixteenByNineJumbo1600',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoSixteenByNineJumbo1600.jpg',
#    'height': 900,
#    'width': 1600,
#    'legacy': {},
#    'subType': 'videoSixteenByNineJumbo1600',
#    'crop_name': 'videoSixteenByNineJumbo1600'},
#   {'rank': 0,
#    'subtype': 'miniMoth',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-miniMoth.jpg',
#    'height': 70,
#    'width': 151,
#    'legacy': {},
#    'subType': 'miniMoth',
#    'crop_name': 'miniMoth'},
#   {'rank': 0,
#    'subtype': 'windowsTile336H',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-windowsTile336H.jpg',
#    'height': 336,
#    'width': 694,
#    'legacy': {},
#    'subType': 'windowsTile336H',
#    'crop_name': 'windowsTile336H'},
#   {'rank': 0,
#    'subtype': 'videoFifteenBySeven1305',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoFifteenBySeven1305.jpg',
#    'height': 609,
#    'width': 1305,
#    'legacy': {},
#    'subType': 'videoFifteenBySeven1305',
#    'crop_name': 'videoFifteenBySeven1305'},
#   {'rank': 0,
#    'subtype': 'videoFifteenBySeven2610',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-videoFifteenBySeven2610.jpg',
#    'height': 1218,
#    'width': 2610,
#    'legacy': {},
#    'subType': 'videoFifteenBySeven2610',
#    'crop_name': 'videoFifteenBySeven2610'},
#   {'rank': 0,
#    'subtype': 'facebookJumbo',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-facebookJumbo.jpg',
#    'height': 550,
#    'width': 1050,
#    'legacy': {},
#    'subType': 'facebookJumbo',
#    'crop_name': 'facebookJumbo'},
#   {'rank': 0,
#    'subtype': 'watch308',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-watch308.jpg',
#    'height': 348,
#    'width': 312,
#    'legacy': {},
#    'subType': 'watch308',
#    'crop_name': 'watch308'},
#   {'rank': 0,
#    'subtype': 'watch268',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-watch268.jpg',
#    'height': 303,
#    'width': 272,
#    'legacy': {},
#    'subType': 'watch268',
#    'crop_name': 'watch268'},
#   {'rank': 0,
#    'subtype': 'verticalTwoByThree735',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-verticalTwoByThree735.jpg',
#    'height': 1102,
#    'width': 735,
#    'legacy': {},
#    'subType': 'verticalTwoByThree735',
#    'crop_name': 'verticalTwoByThree735'},
#   {'rank': 0,
#    'subtype': 'mobileMasterAt3x',
#    'caption': None,
#    'credit': None,
#    'type': 'image',
#    'url': 'images/2022/02/27/multimedia/27mbb-losers1/27mbb-losers1-mobileMasterAt3x.jpg',
#    'height': 1200,
#    'width': 1800,
#    'legacy': {},
#    'subType': 'mobileMasterAt3x',
#    'crop_name': 'mobileMasterAt3x'}],
#  'headline': {'main': 'A Stormy Day for the Top Teams in Men’s College Basketball',
#   'kicker': None,
#   'content_kicker': None,
#   'print_headline': 'Top Six Teams in the Rankings Lose, Pointing to a Wide-Open Postseason',
#   'name': None,
#   'seo': None,
#   'sub': None},
#  'keywords': [{'name': 'subject',
#    'value': 'Basketball (College)',
#    'rank': 1,
#    'major': 'N'},
#   {'name': 'organizations',
#    'value': 'Auburn University',
#    'rank': 2,
#    'major': 'N'},
#   {'name': 'organizations',
#    'value': 'Baylor University',
#    'rank': 3,
#    'major': 'N'},
#   {'name': 'organizations',
#    'value': 'Duke University',
#    'rank': 4,
#    'major': 'N'},
#   {'name': 'organizations',
#    'value': 'Gonzaga University',
#    'rank': 5,
#    'major': 'N'},
#   {'name': 'organizations',
#    'value': 'National Collegiate Athletic Assn',
#    'rank': 6,
#    'major': 'N'},
#   {'name': 'organizations',
#    'value': 'Purdue University',
#    'rank': 7,
#    'major': 'N'},
#   {'name': 'organizations',
#    'value': "St Mary's College of California",
#    'rank': 8,
#    'major': 'N'},
#   {'name': 'organizations',
#    'value': 'Syracuse University',
#    'rank': 9,
#    'major': 'N'},
#   {'name': 'organizations',
#    'value': 'Texas Tech University',
#    'rank': 10,
#    'major': 'N'},
#   {'name': 'organizations',
#    'value': 'University of Arkansas',
#    'rank': 11,
#    'major': 'N'},
#   {'name': 'organizations',
#    'value': 'University of Maryland, Baltimore County',
#    'rank': 12,
#    'major': 'N'},
#   {'name': 'persons', 'value': 'Few, Mark', 'rank': 13, 'major': 'N'},
#   {'name': 'persons', 'value': 'Boeheim, Jim', 'rank': 14, 'major': 'N'},
#   {'name': 'persons', 'value': 'Izzo, Tom', 'rank': 15, 'major': 'N'},
#   {'name': 'persons', 'value': 'Krzyzewski, Mike', 'rank': 16, 'major': 'N'},
#   {'name': 'persons', 'value': 'Musselman, Eric', 'rank': 17, 'major': 'N'}],
#  'pub_date': datetime.datetime(2022, 2, 27, 20, 34, 19, tzinfo=datetime.timezone.utc),
#  'document_type': 'article',
#  'news_desk': 'Sports',
#  'section_name': 'Sports',
#  'subsection_name': 'College Basketball',
#  'byline': {'original': 'By Adam Zagoria',
#   'person': [{'firstname': 'Adam',
#     'middlename': None,
#     'lastname': 'Zagoria',
#     'qualifier': None,
#     'title': None,
#     'role': 'reported',
#     'organization': '',
#     'rank': 1}],
#   'organization': None},
#  'type_of_material': 'News',
#  '_id': 'nyt://article/7b3cfdd2-e906-5331-be64-705a0ce76faf',
#  'word_count': 762,
#  'uri': 'nyt://article/7b3cfdd2-e906-5331-be64-705a0ce76faf'}

# %% [markdown]
# ##### Exercise
#
# Read the documentation, <a href="https://github.com/michadenheijer/pynytimes">https://github.com/michadenheijer/pynytimes</a>, and find the reviews for all books by Maya Angelou using the `book_reviews` endpoint.

# %%
results = nytapi.book_reviews(author = "Maya Angelou")

# %%
results
# Out:
# [{'url': 'http://www.nytimes.com/2002/05/19/books/books-in-brief-nonfiction-982563.html',
#   'publication_dt': datetime.date(2002, 5, 19),
#   'byline': 'PAULA FRIEDMAN',
#   'book_title': 'Song Flung up to Heaven',
#   'book_author': 'Maya Angelou',
#   'summary': '',
#   'uuid': '00000000-0000-0000-0000-000000000000',
#   'uri': 'nyt://book/00000000-0000-0000-0000-000000000000',
#   'isbn13': ['9780553897319']},
#  {'url': 'http://www.nytimes.com/2012/04/22/books/review/philip-larkins-complete-poems.html',
#   'publication_dt': datetime.date(2012, 4, 22),
#   'byline': 'PAUL MULDOON',
#   'book_title': 'The Complete Poems',
#   'book_author': 'Maya Angelou',
#   'summary': 'This sprawling collection of Philip Larkin’s work is accompanied by extensive commentary.',
#   'uuid': '00000000-0000-0000-0000-000000000000',
#   'uri': 'nyt://book/00000000-0000-0000-0000-000000000000',
#   'isbn13': ['9780679428954']},
#  {'url': 'http://www.nytimes.com/1986/05/11/books/part-five-into-africa.html',
#   'publication_dt': datetime.date(1986, 5, 11),
#   'byline': 'HOUSTON A. BAKER JR.',
#   'book_title': "All God's Children Need Traveling Shoes",
#   'book_author': 'Maya Angelou',
#   'summary': '',
#   'uuid': '00000000-0000-0000-0000-000000000000',
#   'uri': 'nyt://book/00000000-0000-0000-0000-000000000000',
#   'isbn13': ['9780394521435']}]

# %% [markdown]
# ## Useful python API wrappers
#
# There are python wrappers for many APIs. Here is a compiled list of some of the most useful <a href="https://github.com/realpython/list-of-python-api-wrappers">https://github.com/realpython/list-of-python-api-wrappers</a>.
#
# If there is a particular site or service that you want data from it can be a good idea to do a simple web search to see if an API exists and if there is a nice python wrapper for it.

# %% [markdown]
# --------------------------
#
# This notebook was written for the Erd&#337;s Institute C&#337;de Data Science Boot Camp by Matthew Osborne, Ph. D., 2022.
#
# Any potential redistributors must seek and receive permission from Matthew Tyler Osborne, Ph.D. prior to redistribution. Redistribution of the material contained in this repository is conditional on acknowledgement of Matthew Tyler Osborne, Ph.D.'s original authorship and sponsorship of the Erdős Institute as subject to the license (see License.md)
